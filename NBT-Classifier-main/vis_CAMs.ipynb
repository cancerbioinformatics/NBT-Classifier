# %%
import os
import glob
import numpy as np
import pandas as pd
import openslide
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt 


import sys
sys.path.append("/scratch_tmp/users/k21066795/NBT-Classifier")
from utils import Reinhard, get_TC, get_TC1024, get_GAPCAM, get_gradCAM, plot_oneline

# %%
model = get_TC1024(weights='/scratch_tmp/prj/cb_normalbreast/prj_BreastAgeNet/CKPTs/MobileNet1024px.h5', output_features=False)
patch_size = 1024

# %% [markdown]
# ## CAMs

# %%
img_path = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/imgs/T18-08826 I1 HE [x=19456,y=90112,w=1024,h=1024].png"
channel = 0
pred_prob, img, CAM, cam_heatmap, super_imposed_cam = get_GAPCAM(img_path = img_path, model = model, layer='conv_pw_13_relu', 
                                                            label_index=channel, with_grids=False, patch_size=patch_size)

plot_oneline(img_list=[img, CAM, cam_heatmap, super_imposed_cam], 
             caption_list=[f'channel_{channel}','',pred_prob,''],
             figure_size=(10, 5),  save_pt=None) # f"{save_pt}{channel}"

pt = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/cams/T18-08826 I1 HE [x=19456,y=90112,w=1024,h=1024]_channel0.png"
plt.figure(figsize=(10, 4)) 
plt.imshow(Image.open(pt))
plt.axis("off")
# Out:
# (-0.5, 2324.5, 567.5, -0.5)

# %%
img_path = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/imgs/T18-08826 I1 HE [x=28672,y=67584,w=1024,h=1024].png"
channel = 2
pred_prob, img, CAM, cam_heatmap, super_imposed_cam = get_GAPCAM(img_path = img_path, model = model, layer='conv_pw_13_relu', 
                                                            label_index=channel, with_grids=False, patch_size=patch_size)

plot_oneline(img_list=[img, CAM, cam_heatmap, super_imposed_cam], 
             caption_list=[f'channel_{channel}','',pred_prob,''],
             figure_size=(10, 5),  save_pt=None) # f"{save_pt}{channel}"

pt = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/cams/T18-08826 I1 HE [x=28672,y=67584,w=1024,h=1024]_channel2.png"
plt.figure(figsize=(10, 4)) 
plt.imshow(Image.open(pt))
plt.axis("off")
# Out:
# (-0.5, 2324.5, 567.5, -0.5)

# %%
img_path = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/imgs/T18-08826 I1 HE [x=69632,y=38912,w=1024,h=1024].png"
# channel = 1
pred_prob, img, CAM, cam_heatmap, super_imposed_cam = get_GAPCAM(img_path = img_path, model = model, layer='conv_pw_13_relu', 
                                                            label_index=channel, with_grids=False, patch_size=patch_size)

plot_oneline(img_list=[img, CAM, cam_heatmap, super_imposed_cam], 
             caption_list=[f'channel_{channel}','',pred_prob,''],
             figure_size=(10, 5),  save_pt=None) # f"{save_pt}{channel}"
# Out:
# (-0.5, 2324.5, 567.5, -0.5)

# %% [markdown]
# ## Grad-CAMs

# %%
img_path = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/imgs/T18-08826 I1 HE [x=19456,y=90112,w=1024,h=1024].png"
channel = 0
pred_prob, img, CAM, cam_heatmap, super_imposed_cam = get_gradCAM(img_path = img_path, model = model, layer='conv_pw_13_relu', 
                                                            label_index=channel, with_grids=False, patch_size=patch_size)

plot_oneline(img_list=[img, CAM, cam_heatmap, super_imposed_cam], 
             caption_list=[f'channel_{channel}','',pred_prob,''],
             figure_size=(10, 5),  save_pt=None) # f"{save_pt}{channel}"
# Out:
# (-0.5, 2324.5, 567.5, -0.5)

# %%
img_path = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/imgs/T18-08826 I1 HE [x=28672,y=67584,w=1024,h=1024].png"
channel = 2
pred_prob, img, CAM, cam_heatmap, super_imposed_cam = get_GAPCAM(img_path = img_path, model = model, layer='conv_pw_13_relu', 
                                                            label_index=channel, with_grids=False, patch_size=patch_size)

plot_oneline(img_list=[img, CAM, cam_heatmap, super_imposed_cam], 
             caption_list=[f'channel_{channel}','',pred_prob,''],
             figure_size=(10, 5),  save_pt=None) # f"{save_pt}{channel}"
# Out:
# (-0.5, 2324.5, 567.5, -0.5)

# %%
img_path = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/CAMs/1024px/imgs/T18-08826 I1 HE [x=69632,y=38912,w=1024,h=1024].png"
channel = 1
pred_prob, img, CAM, cam_heatmap, super_imposed_cam = get_gradCAM(img_path = img_path, model = model, layer='conv_pw_13_relu', 
                                                            label_index=channel, with_grids=False, patch_size=patch_size)

plot_oneline(img_list=[img, CAM, cam_heatmap, super_imposed_cam], 
             caption_list=[f'channel_{channel}','',pred_prob,''],
             figure_size=(10, 5),  save_pt=None) # f"{save_pt}{channel}"
# Out:
# (-0.5, 2324.5, 567.5, -0.5)
